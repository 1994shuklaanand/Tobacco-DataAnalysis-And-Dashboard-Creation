# %% [markdown]
# <a href="https://colab.research.google.com/github/1994shuklaanand/Tobacco-DataAnalysis-And-Dashboard-Creation/blob/main/Tobacco_DataAnalysis_And_Dashboard_Creation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
table=pd.read_html('https://www.findeasy.in/tobacco-use-among-adults-in-india/')

# %%
len(table)
# Out:
# 3

# %%
table[0]
# Out:
#       0                           1                         2  \
# 0     #  States & Union Territories  Women (15 years & above)
# 1     1           Andaman & Nicobar                    31.3 %
# 2     2                          AP                      3.8%
# 3     3                   Arunachal                     18.8%
# 4     4                       Assam                     22.1%
# 5     5                       Bihar                      5.0%
# 6     6                  Chandigarh                      0.6%
# 7     7                Chattishgarh                     17.3%
# 8     8                         D&N                      2.9%
# 9     9                       Delhi                      2.2%
# 10   10                         Goa                      2.6%
# 11   11                     Gujarat                      8.7%
# 12   12                     Haryana                      2.5%
# 13   13            Himachal Pradesh                      1.7%
# ...

# %%
csv_file_path = pd.read_csv('/content/tobaco1.csv')

# %%
final_tobaco = pd.read_excel('/content/TOBACO FINAL.xlsx')

# %%
final_tobaco.head()
# Out:
#   States & UnionÂ Territories  Women (15 years & above)  \
# 0           Andaman & Nicobar                     0.313
# 1                          AP                     0.038
# 2                   Arunachal                     0.188
# 3                       Assam                     0.221
# 4                       Bihar                     0.050
#
#    Men (15 years & above)
# 0                   0.587
# 1                   0.226
# 2                   0.503
# 3                   0.518
# 4                   0.488

# %%
csv_file_path.head()
# Out:
#   States & Union Territories Women (15 years & above) Men (15 years & above)
# 0          Andaman & Nicobar                   31.30%                 58.70%
# 1                         AP                    3.80%                 22.60%
# 2                  Arunachal                   18.80%                 50.30%
# 3                      Assam                   22.10%                 51.80%
# 4                      Bihar                    5.00%                 48.80%

# %%
table[0].to_csv('/content/tobaco1.csv' , index=False)
